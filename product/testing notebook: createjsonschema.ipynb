# %%
import sys
import json
import os

# %%
parent_dir = os.path.abspath('..') 
if parent_dir not in sys.path:
    print(f'Adding {parent_dir} to path')
    sys.path.append(parent_dir) # Adjust path as needed

import createjsonschema
import createtablefromjsonschema

# %%
jsonschemaname = 'testtable'
domain = 'tables'
jsonschemadescription = 'This is a jsonschema file defining the table for validating a product record'

objectsting = json.dumps({})

objectsting = createjsonschema.schema(jsonschemaname,objectsting).schema("testschema").add()
objectsting = createjsonschema.schema(jsonschemaname,objectsting).schema("testschema").modify("testschema2")
objectsting = createjsonschema.schema(jsonschemaname,objectsting).schema("testschema2").remove()

print(json.dumps(json.loads(objectsting), indent=4))
